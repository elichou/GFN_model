# %%
import GFN_model

# %%
model = GFN_model.GFN_encoder()
dec = GFN_model.GFN_decoder()

# %%
print(model.dtype)
# Out:
# None

# %%
print(model.dtype)
# Out:
# None

# %%
model.layers

# %%
dec.layers

# %%
model.__setattr__(input_spec, (1,128,128,))

# %%
autoencoder = GFN_model.GFN_autoencoder()

# %%
dir(autoencoder)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_activity_regularizer',
#  '_add_inbound_node',
#  '_add_unique_metric_name',
#  '_add_variable_with_custom_getter',
#  '_all_metrics_tensors',
#  '_all_stateful_metrics_tensors',
#  '_base_init',
#  '_cache_output_metric_attributes',
#  '_call_and_compute_mask',
#  '_call_convention',
#  '_call_is_graph_friendly',
#  '_check_trainable_weights_consistency',
#  '_checkpoint_dependencies',
#  '_checkpointable_saver',
#  '_clear_losses',
#  '_compute_output_and_mask_jointly',
#  '_dataset_iterator_cache',
#  '_default_save_signature',
#  '_deferred_dependencies',
#  '_determine_call_convention',
#  '_distribution_standardize_user_data',
#  '_distribution_strategy',
# ...

# %%
autoencoder.__dict__
# Out:
# {'_activity_regularizer': None,
#  '_call_convention': <CallConvention.SINGLE_POSITIONAL_ARGUMENT: 2>,
#  '_call_is_graph_friendly': True,
#  '_checkpointable_saver': <tensorflow.python.training.checkpointable.util.CheckpointableSaver at 0x7f530e170c50>,
#  '_compute_output_and_mask_jointly': False,
#  '_dataset_iterator_cache': <WeakKeyDictionary at 139994696089968>,
#  '_distribution_strategy': None,
#  '_dtype': None,
#  '_eager_losses': [],
#  '_expects_training_arg': False,
#  '_graph': <tensorflow.python.framework.ops.Graph at 0x7f530e284150>,
#  '_inbound_nodes': [],
#  '_is_compiled': False,
#  '_is_graph_network': False,
#  '_iterator_get_next': <WeakKeyDictionary at 139994696089680>,
#  '_layers': [ListWrapper(['image', 'image']),
#   ListWrapper(['dense']),
# ...
#  '_losses': [],
#  '_metrics': [],
#  '_metrics_tensors': {},
#  '_name': 'GFN_autoencoder',
#  '_name_based_restores': set(),
#  '_non_trainable_weights': [],
#  '_outbound_nodes': [],
#  '_reuse': None,
# ...

# %%
model.__dict__
# Out:
# {'_activity_regularizer': None,
#  '_call_convention': <CallConvention.SINGLE_POSITIONAL_ARGUMENT: 2>,
#  '_call_is_graph_friendly': True,
#  '_checkpointable_saver': <tensorflow.python.training.checkpointable.util.CheckpointableSaver at 0x7f530e284310>,
#  '_compute_output_and_mask_jointly': False,
#  '_dataset_iterator_cache': <WeakKeyDictionary at 139994696599384>,
#  '_distribution_strategy': None,
#  '_dtype': None,
#  '_eager_losses': [],
#  '_expects_training_arg': False,
#  '_graph': <tensorflow.python.framework.ops.Graph at 0x7f530e284150>,
#  '_inbound_nodes': [],
#  '_is_compiled': False,
#  '_is_graph_network': False,
#  '_iterator_get_next': <WeakKeyDictionary at 139994696599240>,
#  '_layers': [ListWrapper(['image', 'image']),
#   ListWrapper(['dense']),
# ...
#  '_losses': [],
#  '_metrics': [],
#  '_metrics_tensors': {},
#  '_name': 'GFN_encoder',
#  '_name_based_restores': set(),
#  '_non_trainable_weights': [],
#  '_outbound_nodes': [],
#  '_reuse': None,
# ...
